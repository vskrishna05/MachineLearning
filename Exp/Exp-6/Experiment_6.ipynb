# %%
import pandas as pd

df = pd.read_csv("Global_Operative_Dataset.csv")
print("Dataset loaded successfully!")
# Out:
# Dataset loaded successfully!

# %%
df.head(10)
# Out:
#                 name  gender    status  affiliation          faction  \
# 0   Michael Carter 1  Female  Inactive  Continental          Handler
# 1      Ryan Carter 2    Male  Inactive  Continental       Contractor
# 2  Benjamin Hunter 3  Female    Active  Continental  Crime Syndicate
# 3    Oliver Walker 4  Female   Missing   Underworld         Security
# 4    Joseph Brooks 5  Female  Inactive  Independent         Assassin
# 5     William Ward 6  Female  Inactive   High Table         Security
# 6     Joseph Hayes 7    Male  Deceased   Ruska Roma         Security
# 7      Ryan Turner 8  Female   Missing  Independent          Handler
# 8     James Foster 9    Male  Inactive   Underworld       Contractor
# 9   Lucas Bennett 10  Female    Active  Independent         Assassin
#
#         role   weapon     emotion  mission_count    location    rank   loyalty
# 0  Operative   Pistol     Neutral            189      London  Novice  Absolute
# ...

# %%
df.tail(10)
# Out:
#                          name  gender    status  affiliation          faction  \
# 99990      Lucas Hunter 99991  Female   Missing   High Table         Security
# 99991    William Hunter 99992    Male   Missing  Independent       Contractor
# 99992     David Griffin 99993    Male    Active   Underworld         Assassin
# 99993      David Walker 99994    Male   Missing  Independent         Assassin
# 99994        Leo Walker 99995  Female    Active   Underworld  Crime Syndicate
# 99995      Jack Griffin 99996  Female    Active  Continental       Contractor
# 99996  Benjamin Collins 99997  Female  Deceased  Continental  Crime Syndicate
# 99997       Thomas Reed 99998  Female  Deceased   High Table         Assassin
# 99998      James Foster 99999    Male   Missing  Continental  Crime Syndicate
# 99999    Samuel Morgan 100000    Male   Missing   High Table         Security
#
#             role   weapon     emotion  mission_count    location  \
# ...

# %%
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])
# Out:
# Rows: 100000
# Columns: 12

# %%
print(df.columns)
# Out:
# Index(['name', 'gender', 'status', 'affiliation', 'faction', 'role', 'weapon',
#        'emotion', 'mission_count', 'location', 'rank', 'loyalty'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 12 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   name           100000 non-null  object
#  1   gender         100000 non-null  object
#  2   status         100000 non-null  object
#  3   affiliation    100000 non-null  object
#  4   faction        100000 non-null  object
#  5   role           100000 non-null  object
#  6   weapon         100000 non-null  object
#  7   emotion        100000 non-null  object
#  8   mission_count  100000 non-null  int64
#  9   location       100000 non-null  object
#  10  rank           100000 non-null  object
#  11  loyalty        100000 non-null  object
# dtypes: int64(1), object(11)
# memory usage: 9.2+ MB

# %%
print(df.isnull().sum())
# Out:
# name             0
# gender           0
# status           0
# affiliation      0
# faction          0
# role             0
# weapon           0
# emotion          0
# mission_count    0
# location         0
# rank             0
# loyalty          0
# dtype: int64

# %%
print("Duplicate records:", df.duplicated().sum())
# Out:
# Duplicate records: 0

# %%
print(df["gender"].value_counts())
# Out:
# gender
# Male      50021
# Female    49979
# Name: count, dtype: int64

# %%
print(df["status"].value_counts())
# Out:
# status
# Active      25131
# Missing     25104
# Inactive    24936
# Deceased    24829
# Name: count, dtype: int64

# %%
print(df["location"].value_counts())
# Out:
# location
# London        10134
# Casablanca    10120
# Osaka         10078
# Rome          10055
# Prague        10005
# Tokyo          9961
# Marrakesh      9926
# Paris          9919
# Berlin         9918
# New York       9884
# Name: count, dtype: int64

# %%
print(df["rank"].value_counts())
# Out:
# rank
# Senior Agent    20272
# Master          20257
# Novice          19995
# Agent           19760
# Elite           19716
# Name: count, dtype: int64

# %%
print(df["weapon"].value_counts())
# Out:
# weapon
# Unarmed    16880
# Knife      16717
# Sword      16662
# Pistol     16616
# Rifle      16587
# Shotgun    16538
# Name: count, dtype: int64

# %%
print("Average missions:", df["mission_count"].mean())
# Out:
# Average missions: 124.98727

# %%
print("Maximum missions:", df["mission_count"].max())
# Out:
# Maximum missions: 250

# %%
print("Minimum missions:", df["mission_count"].min())
# Out:
# Minimum missions: 0

# %%
df.sort_values("mission_count", ascending=False).head(10)
# Out:
#                       name  gender    status  affiliation     faction  \
# 8945   Michael Brooks 8946  Female  Deceased   Ruska Roma    Assassin
# 8947    Daniel Bailey 8948    Male  Inactive   Underworld    Security
# 37358    Alex Morgan 37359  Female   Missing   Ruska Roma  Contractor
# 5971    Samuel Murphy 5972  Female    Active   Underworld  Contractor
# 37721  William Hayes 37722    Male  Inactive   Ruska Roma    Assassin
# 9876       Leo Turner 9877    Male   Missing  Continental     Handler
# 9751    Andrew Bailey 9752    Male   Missing   Underworld    Security
# 9707   Lucas Mitchell 9708  Female   Missing   Ruska Roma     Handler
# 99316   Ethan Cooper 99317  Female  Inactive   Ruska Roma    Assassin
# 9380     David Morgan 9381  Female    Active   Ruska Roma     Handler
#
#             role   weapon     emotion  mission_count   location          rank  \
# 8945      Hitman   Pistol       Angry            250      Paris  Senior Agent
# ...

# %%
name = input("Enter operative name: ")

result = df[
    df["name"].str.contains(name, case=False, na=False)
]

display(result)
# Out:
# Enter operative name: mission codex
# Empty DataFrame
# Columns: [name, gender, status, affiliation, faction, role, weapon, emotion, mission_count, location, rank, loyalty]
# Index: []

# %%
result = df[df["mission_count"] > 100]

print("Number of operatives:", len(result))
display(result.head(20))
# Out:
# Number of operatives: 59633
#                    name  gender    status  affiliation          faction  \
# 0      Michael Carter 1  Female  Inactive  Continental          Handler
# 3       Oliver Walker 4  Female   Missing   Underworld         Security
# 5        William Ward 6  Female  Inactive   High Table         Security
# 8        James Foster 9    Male  Inactive   Underworld       Contractor
# 9      Lucas Bennett 10  Female    Active  Independent         Assassin
# 10     Oliver Cooper 11  Female   Missing   Underworld         Assassin
# 11    Michael Brooks 12  Female  Inactive   Ruska Roma         Assassin
# 12     Henry Russell 13    Male  Inactive   High Table          Handler
# 13  Michael Mitchell 14  Female  Inactive  Independent          Handler
# 14      James Bailey 15    Male   Missing   Underworld       Contractor
# 15          Leo Ward 16  Female    Active  Continental          Handler
# 17    Joseph Bennett 18  Female  Inactive   Ruska Roma  Crime Syndicate
# ...

# %%
result = df.groupby("rank")["mission_count"].mean()

print(result)
# Out:
# rank
# Agent           125.911083
# Elite           124.467793
# Master          125.469072
# Novice          124.768992
# Senior Agent    124.325868
# Name: mission_count, dtype: float64
